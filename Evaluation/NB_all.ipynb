# %% [markdown]
# ## Setup

# %%
import pandas as pd
import os
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

# %%
# Get File Paths
google_drive_path = "/Users/andrewstange/Desktop/CMU/Spring_2023/80-816/project/Project_80816/data"

filename = "ChurnForBankCustomers_optbinning.csv"

full_filename = os.path.join(google_drive_path, filename)

assert os.path.isfile(full_filename)

# %%
# Convert dataframe to numpy array
df = pd.read_csv(full_filename)
display(df.dtypes)
display(df.head(5))
# Out:
# CreditScore         int64
# Geography          object
# Gender             object
# Age                 int64
# Tenure              int64
# Balance             int64
# NumOfProducts       int64
# HasCrCard            bool
# IsActiveMember       bool
# EstimatedSalary     int64
# Exited               bool
# dtype: object
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0            2    France  Female    6       1        0              0
# 1            2     Spain  Female    6       0        1              0
# 2            1    France  Female    6       4        6              1
# 3            5    France  Female    5       0        0              1
# 4            7     Spain  Female    7       1        5              0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0       True            True                3    True
# 1      False            True                4   False
# 2       True           False                4    True
# 3      False           False                3   False
# 4       True            True                2   False

# %%
for col in df.columns:
    unique_vals = sorted(df[col].unique())
    data_to_num = {data: num for num, data in enumerate(unique_vals)}
    df[col] = df[col].map(data_to_num)

display(df.dtypes)
display(df.head(5))
# Out:
# CreditScore        int64
# Geography          int64
# Gender             int64
# Age                int64
# Tenure             int64
# Balance            int64
# NumOfProducts      int64
# HasCrCard          int64
# IsActiveMember     int64
# EstimatedSalary    int64
# Exited             int64
# dtype: object
#    CreditScore  Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0            2          0       0    6       1        0              0
# 1            2          2       0    6       0        1              0
# 2            1          0       0    6       4        6              1
# 3            5          0       0    5       0        0              1
# 4            7          2       0    7       1        5              0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1                3       1
# 1          0               1                4       0
# 2          1               0                4       1
# 3          0               0                3       0
# 4          1               1                2       0

# %% [markdown]
# ## Evaluate Naive Bayes Classifier using All Features

# %%
X = df.drop('Exited', axis=1).to_numpy()
y = df['Exited'].to_numpy()

# 5-fold cross validation of MultinomialNB
scores = cross_val_score(MultinomialNB(), X, y)
print(scores)
# Out:
# [0.8015 0.816  0.807  0.814  0.802 ]
